# %%
with open("/mario-gpt/notebooks/test_level.txt", "r") as file:
    file_contents = file.read()

print(file_contents)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------xxxx--------------------------------------------------------------------------
# --------------xxxxx--xx---x----------------------------------------------------------------------xxx
# -------------xx----xxx-----xxxxx-------------------------------------------------------xxxx----xxx--
# ------------xxX-----x-------x---x---------------------QQQ---E-E-E------------S--------xx---x--xxXS--
# -----------xxXX----XX------XX----x-------------------------<><><>--------------------xx-----xxxEX---
# ---xx-----xxXXXXX-----------------x------------------------[][][]-------------------xx-------xXXX---
# --xx-x---xxXXXX--------------------xxxxx-------------------QQQQQQ--------------xxxxxx--------XXXXS--
# -xx---x-xxXXXXX---------------------xXX-xSSS------------------------------Q--xxx---<>-------XXXXX---
# xx-----xxXXXXXX---------------------XXX--x---------------------------xxxx---xx<>---[]------XXXXXX---
# x------XXXXXXXX-E------------------XXXX---x------------Exxx---------xx<>-x-xx-[]---[]-----XXXXXXX---
# X------XXXXXXXX<>-----------------XXXXX----xxxxxxxxxxxxxx--xxxxxxxxxx-[]--xx--[]---[]----XXXXXXXX---
# X------XXXXXXXX[]-----------------XXXXXXXXXXXXXXXXXXXXXXX--XXXXXXXXXXXXXX-XXX-XX--XXXXX-XXXXXXXXXXXX

# %%
from mario_gpt.prompter import Prompter
from mario_gpt.prompt_adapter import PromptAdapter

# Create a Prompter instance
tokenizer_path = "shyamsn97/Mario-GPT2-700-context-length"
prompter = Prompter(level_tokenizer=tokenizer_path)  

# Create the PromptAdapter
adapter = PromptAdapter(prompter=prompter)

# Generate a new adapted prompt
level_data = file_contents
adapted_prompt = adapter.new_prompter(level_data)

print("Adapted Prompt:", adapted_prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from mario_gpt.prompt_adapter import PromptAdapter
#       4 # Create a Prompter instance
# ----> 5 level_tokenizer = AutoTokenizer.from_pretrained("facebook/bart-base")
#       6 prompter = Prompter(level_tokenizer=level_tokenizer)
#       8 # Create the PromptAdapter
#
# NameError: name 'AutoTokenizer' is not defined
